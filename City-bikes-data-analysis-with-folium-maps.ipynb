# %% [markdown]
# # Read the pre-processed station data and the trips data

# %%
import h3
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
import numpy as np
import glob
import os
import datetime

import geopandas as gpd
import shapely
from shapely import wkt
from shapely import Polygon
from shapely.plotting import plot_polygon

from matplotlib.ticker import FuncFormatter

import branca
from branca.element import Element
from geojson import Feature, Point, FeatureCollection
import folium
from h3 import h3
import json
import leafmap.foliumap as leafmap
import math

pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 100)

#Set color palette in code
colors = ['#8468F5','#EC74E7','#B2B2B2','#FFCB5C','#46B6E8','#2FD4A1','#333333']
sns.set_palette(sns.color_palette(colors), n_colors = 20)

# %%
# Stations:
file_path = './bike_data/city-bike-stations-cleaned.csv'
df_stations = pd.read_csv(file_path)


# Bike trips:
directory_path = './bike_data/city-bike-trips-cleaned.csv'
df_trips = pd.read_csv(directory_path)

# Change the timestamps into datetime
df_trips['Departure'] = pd.to_datetime(df_trips['Departure'])
df_trips['Return'] = pd.to_datetime(df_trips['Return'])

df_trips['departure_date'] = pd.to_datetime(df_trips['departure_date'])
df_trips['return_date'] = pd.to_datetime(df_trips['return_date'])

# %% [markdown]
# # Folium visualizations

# %% [markdown]
# ## Define functions for plotting

# %%
center_lng = df_stations.lng.mean()
center_lat = df_stations.lat.mean()


def init_map(zoom=11):
    return folium.Map(location= [center_lat, center_lng], zoom_start=zoom, tiles="cartodbpositron")

def visualize_hexagons(hexagons, color="black", fill_color="purple", w=2, folium_map=None, fill_opacity=0.2):
    """
    hexagons is a list of hexcluster. Each hexcluster is a list of hexagons. 
    eg. [[hex1, hex2], [hex3, hex4]]
    """
    polylines = []
    lat = []
    lng = []
    for hex in hexagons:
        polygons = h3.h3_set_to_multi_polygon([hex], geo_json=False)
        # flatten polygons into loops.
        outlines = [loop for polygon in polygons for loop in polygon]
        polyline = [outline + [outline[0]] for outline in outlines][0]
        lat.extend(map(lambda v:v[0],polyline))
        lng.extend(map(lambda v:v[1],polyline))
        polylines.append(polyline)
    
    if folium_map is None:
        m = init_map()
    else:
        m = folium_map
    for polyline in polylines:
        my_PolyLine=folium.PolyLine(locations=polyline, weight=w, color=color, fill_color=fill_color,
                                    fill_opacity=fill_opacity)
        m.add_child(my_PolyLine)
    return m

def visualize_points(lat, lng, color='black', folium_map=None, r=2):
    if folium_map is None:
        m = init_map()
    else:
        m = folium_map
        
    for i in range(0, len(lat)):
        scatter_marker = folium.CircleMarker(location=[lat[i], lng[i]], radius=r, color=color, fill_color=color)
        m.add_child(scatter_marker)
        
    return m
    

def visualize_polygon(polyline, color):
    polyline.append(polyline[0])
    lat = [p[0] for p in polyline]
    lng = [p[1] for p in polyline]
    m = folium.Map(location=[center_lat, center_lng], zoom_start=13, tiles='openstreetmap')
    my_PolyLine=folium.PolyLine(locations=polyline,weight=8,color=color)
    m.add_child(my_PolyLine)
    return m

def visualize_line(start_lat, start_lng, end_lat, end_lng, color='red', w=2, folium_map=None):
    if folium_map is None:
        m = init_map()
    else:
        m = folium_map
        
    for i in range(0, len(start_lat)):
        line = folium.PolyLine(locations = [[start_lat[i], start_lng[i]], [end_lat[i], end_lng[i]]],
                               weight=w, color=color)
        m.add_child(line)
    return m

# %% [markdown]
# The following code includes parts taken from: https://gist.github.com/jens-andersson-2-wcar/7cecb40db1fbc051f2822262be42d11b

# %%
center_lng = df_stations.lng.mean()
center_lat = df_stations.lat.mean()

# Rounding functions to round the values to closest magnitude
def roundup(x, magnitude=100):
     return int(math.ceil(x / magnitude)) * magnitude
    
def rounddown(x, magnitude=100):
     return int(math.floor(x / magnitude)) * magnitude

# Taken from: https://gist.github.com/jens-andersson-2-wcar/7cecb40db1fbc051f2822262be42d11b

def hexagons_dataframe_to_geojson(df, hexa_col, column_name):
    """
    Produce the GeoJSON for a dataframe, constructing the geometry from the "hex_id" column
    and with a property matching the one in column_name
    """    
    list_features = []
    
    for i,row in df.iterrows():
        try:
            geometry_for_row = { "type" : "Polygon",
                                "coordinates": [h3.h3_to_geo_boundary(h=row[hexa_col],geo_json=True)]}
            feature = Feature(geometry = geometry_for_row , id = row[hexa_col],
                              properties = {column_name : row[column_name]})
            list_features.append(feature)
        except:
            print("An exception occurred for hex " + row[hexa_col]) 

    feat_collection = FeatureCollection(list_features)
    geojson_result = json.dumps(feat_collection)
    return geojson_result


def get_color(custom_cm, val, vmin, vmax):
    return matplotlib.colors.to_hex(custom_cm((val-vmin)/(vmax-vmin)))


def choropleth_map(df_aggreg, hexa_col, column_name, border_color = 'black', fill_opacity = 0.7,
                   color_map_name = "Purples", initial_map = None, min_value=None, max_value=None,
                   color_map_caption = None):
    """
    Creates choropleth maps given the aggregated data. initial_map can be an existing map to draw on top of.
    """    
    #colormap
    if min_value==None:
        min_value = df_aggreg[column_name].min()
    if max_value == None:
        max_value = df_aggreg[column_name].max()
        
            
    # the name of the layer just needs to be unique, put something silly there for now:
    name_layer = "Choropleth " + str(df_aggreg)
    
    if initial_map is None:
        initial_map = init_map()

    #create geojson data from dataframe
    geojson_data = hexagons_dataframe_to_geojson(df = df_aggreg, hexa_col=hexa_col, column_name=column_name)

    custom_cm = matplotlib.cm.get_cmap(color_map_name)

    folium.GeoJson(
        geojson_data,
        style_function=lambda feature: {
            'fillColor': get_color(custom_cm, feature['properties'][column_name], vmin=min_value, vmax=max_value),
            'color': border_color,
            'weight': 1,
            'fillOpacity': fill_opacity 
        }, 
        name = name_layer
    ).add_to(initial_map)
    
    # Create a colorbar legend
    color_min = get_color(custom_cm, min_value, vmin=min_value, vmax=max_value)
    color_max = get_color(custom_cm, max_value, vmin=min_value, vmax=max_value)
    color_scale = folium.LinearColormap([color_min, color_max], vmin=min_value, vmax=max_value)
    # Add the colorbar legend to the map
    if color_map_caption == None:
        color_scale.caption = column_name
    else:
        color_scale.caption = color_map_caption
    initial_map.add_child(color_scale)

        

    return initial_map

def add_categorical_legend(m, plot_colors, indexes, text):
    ticks = np.add(indexes, 0.5).tolist()
    colormap = branca.colormap.StepColormap(colors=plot_colors, index=indexes, tick_labels= ticks,
                                            vmin=indexes[0], vmax=indexes[-1]+1)
    colormap.caption = text
    
    m.add_child(colormap)
    e = Element("""
                var ticks = document.querySelectorAll('div.legend g.tick text')
                for(var i = 0; i < ticks.length; i++) {
                    var value = parseFloat(ticks[i].textContent.replace(',', ''))
                    var newvalue = Math.floor(value).toFixed(0).toString()
                    ticks[i].textContent = newvalue
                }
                """)
    html = colormap.get_root()
    html.script.get_root().render()
    html.script.add_child(e)

# %% [markdown]
# ## Visualize the data

# %%
# Plot the station and the year they were added to the city bike network
m = init_map(zoom=11.5)
use_data = df_stations[df_stations.Year==2016]
visualize_points(use_data.lat.tolist(), use_data.lng.tolist(), folium_map=m, color=colors[0])
use_data = df_stations[df_stations.Year==2017]
visualize_points(use_data.lat.tolist(), use_data.lng.tolist(), folium_map=m, color=colors[1])
use_data = df_stations[df_stations.Year==2018]
visualize_points(use_data.lat.tolist(), use_data.lng.tolist(), folium_map=m, color=colors[2])
use_data = df_stations[df_stations.Year==2019]
visualize_points(use_data.lat.tolist(), use_data.lng.tolist(), folium_map=m, color=colors[3])
use_data = df_stations[df_stations.Year==2020]
visualize_points(use_data.lat.tolist(), use_data.lng.tolist(), folium_map=m, color=colors[4])
use_data = df_stations[df_stations.Year==2021]
visualize_points(use_data.lat.tolist(), use_data.lng.tolist(), folium_map=m, color=colors[5])
add_categorical_legend(m, [colors[0], colors[1], colors[2], colors[3], colors[4], colors[5]], 
                       [2016, 2017, 2018, 2019, 2020, 2021], 'Year station was added')

m.save("images/station_year.html")
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_03264f9c9a84827a8eb1b7ca8e318c4d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_03264f9c9a84827a8eb1b7ca8e318c4d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_03264f9c9a84827a8eb1b7ca8e318c4d = L.map(
#                 &quot;map_03264f9c9a84827a8eb1b7ca8e318c4d&quot;,
#                 {
#                     center: [60.20085851110746, 24.928136680658007],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bacb0e5bb3a8a2f08318105e032a197c = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_bacb0e5bb3a8a2f08318105e032a197c.addTo(map_03264f9c9a84827a8eb1b7ca8e318c4d);
#
#
#             var circle_marker_342e30a445a0dc1e5df2c5ff3ec13878 = L.circleMarker(
#                 [60.155369615074, 24.9502114714031],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8468F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#8468F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_03264f9c9a84827a8eb1b7ca8e318c4d);
#
#
#             var circle_marker_9ed0a9283e6df62fc215571937c81cf1 = L.circleMarker(
#                 [60.1609890692806, 24.9565097715858],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8468F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#8468F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_03264f9c9a84827a8eb1b7ca8e318c4d);
#
#
#             var circle_marker_37fa9d2701caa95f8c456ac016c9ec3d = L.circleMarker(
#                 [60.1581769029949, 24.9450181631667],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8468F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#8468F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_03264f9c9a84827a8eb1b7ca8e318c4d);
#
#
#             var circle_marker_3de55904c68de5540a355ecc2de75c09 = L.circleMarker(
#                 [60.1609858921764, 24.9417758006418],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8468F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#8468F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_03264f9c9a84827a8eb1b7ca8e318c4d);
#
#
#             var circle_marker_3a0f1399e56586f729c17e40c5c25065 = L.circleMarker(
#                 [60.157948291819, 24.9362853002102],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8468F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#8468F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_03264f9c9a84827a8eb1b7ca8e318c4d);
#
#
#             var circle_marker_54a7017534cfd4ec63d3eab223a0021c = L.circleMarker(
#                 [60.1622283898112, 24.9296476311878],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8468F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#8468F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;r

# %%
# Plot the average covered distance by the return station
col_hexa = 'return_h3_res8'
col_by = 'Covered distance (m)'

#num_trips = df_trips.groupby([col_hexa,'return_date'])[[col_by]].mean().reset_index()
num_trips = df_trips.groupby([col_hexa])[[col_by]].mean().reset_index()

plot_map = choropleth_map(num_trips, hexa_col=col_hexa, column_name = 'Covered distance (m)',
                          min_value=rounddown(num_trips[col_by].min()), max_value=roundup(num_trips[col_by].max()),
                          fill_opacity=0.9,
                          color_map_caption = 'Average covered distance (m) by return station')

plot_map.save("images/covered_distance_byhexagon.html")
display(plot_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d58af65c4ddd6c0de343f569cf0572e9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d58af65c4ddd6c0de343f569cf0572e9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d58af65c4ddd6c0de343f569cf0572e9 = L.map(
#                 &quot;map_d58af65c4ddd6c0de343f569cf0572e9&quot;,
#                 {
#                     center: [60.20085851110746, 24.928136680658007],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2c1a3d8fafa9115ab2d5b456df8aa2ed = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2c1a3d8fafa9115ab2d5b456df8aa2ed.addTo(map_d58af65c4ddd6c0de343f569cf0572e9);
#
#
#         function geo_json_69def642d7a4705aefb0b23504aa77b4_styler(feature) {
#             switch(feature.id) {
#                 case &quot;8808996807fffff&quot;: case &quot;881126d00bfffff&quot;: case &quot;881126d0bbfffff&quot;: case &quot;881126d0e3fffff&quot;: case &quot;881126d285fffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#7d77b7&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;8808996821fffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#eae8f2&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;8808996823fffff&quot;: case &quot;8808996951fffff&quot;: case &quot;881126c265fffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c8c8e2&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;8808996825fffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#dedeed&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;8808996827fffff&quot;: case &quot;8808996829fffff&quot;: case &quot;881126c359fffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#e0e0ee&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;880899682bfffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#8e8ac0&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;880899682dfffff&quot;: case &quot;880899698bfffff&quot;: case &quot;881126d72dfffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ecebf4&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;8808996833fffff&quot;: case &quot;881126d76dfffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#6d57a6&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;8808996867fffff&quot;: case &quot;881126d0a5fffff&quot;: case &quot;881126d0d1fffff&quot;: case &quot;881126d19dfffff&quot;: case &quot;881126d309fffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#dadaeb&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;8808996885fffff&quot;: case &quot;88089968a1fffff&quot;: case &quot;88089968b5fffff&quot;: case &quot;881126d0cbfffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#e0dfee&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;8808996887fffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#edebf4&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;88089968a3fffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f6f5f9&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;88089968a5fffff&quot;: case &quot;881126d217fffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#7970b3&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;88089968a7fffff&quot;: case &quot;88089969cdfffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#e2e2ef&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;88089968a9fffff&quot;: case &quot;881126d301fffff&quot;:
#                     return {&q

# %%
m = init_map(zoom=11.5)
visualize_hexagons(df_stations.h3_res8.unique().tolist(), color="black", fill_color=None, w=0.5, folium_map=m)
visualize_hexagons(df_stations.h3_res7.unique().tolist(), color="gray", fill_color=None, w=1.5, folium_map=m)
visualize_hexagons(df_stations.h3_res6.unique().tolist(), color="dimgray", fill_color=None, w=2, folium_map=m)

visualize_points(df_stations.lat.tolist(), df_stations.lng.tolist(), folium_map=m, color=colors[0], r=2)

m.save("images/hexagons_at_different_resolutions.html")

display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7438fba75e70c394cc60efc02b939a3a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7438fba75e70c394cc60efc02b939a3a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7438fba75e70c394cc60efc02b939a3a = L.map(
#                 &quot;map_7438fba75e70c394cc60efc02b939a3a&quot;,
#                 {
#                     center: [60.20085851110746, 24.928136680658007],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6de928c69e206e9b663f5bfd313dc1ea = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6de928c69e206e9b663f5bfd313dc1ea.addTo(map_7438fba75e70c394cc60efc02b939a3a);
#
#
#             var poly_line_307d2f0e3af0bc38becf935b4884b548 = L.polyline(
#                 [[60.17150188544707, 24.849313413544447], [60.17016295641156, 24.841728972338363], [60.16574934264519, 24.83974175951051], [60.16267455960363, 24.845337116707608], [60.16401304040454, 24.852920312898643], [60.1684267524381, 24.854909396828152], [60.17150188544707, 24.849313413544447]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 0.5}
#             ).addTo(map_7438fba75e70c394cc60efc02b939a3a);
#
#
#             var poly_line_96a2301b68d8c438d457abe4f7732063 = L.polyline(
#                 [[60.166144167309504, 24.818982735705195], [60.1674840971856, 24.82656363342911], [60.17189761244241, 24.82854897506533], [60.17497109911464, 24.82295154777555], [60.17363072084349, 24.81536940638303], [60.169217304338645, 24.813385936027927], [60.166144167309504, 24.818982735705195]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 0.5}
#             ).addTo(map_7438fba75e70c394cc60efc02b939a3a);
#
#
#             var poly_line_53ca112de2051e6b55b01f7d438638ad = L.polyline(
#                 [[60.167876650341505, 24.805806188634456], [60.169217304338645, 24.813385936027927], [60.17363072084349, 24.81536940638303], [60.17670338440036, 24.809771258053598], [60.17536228192808, 24.80219026766528], [60.170948964417576, 24.800208668680035], [60.167876650341505, 24.805806188634456]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 0.5}
#             ).addTo(map_7438fba75e70c394cc60efc02b939a3a);
#
#
#             var poly_line_ff9d46877cfc71632d032c9986dfd74f = L.polyline(
#                 [[60.16346330781702, 24.803824483665725], [60.167876650341505, 24.805806188634456], [60.170948964417576, 24.800208668680035], [60.16960758657717, 24.792630072347652], [60.16519434324245, 24.790650238043458], [60.16212237851493, 24.79624712932841], [60.16346330781702, 24.803824483665725]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 0.5}
#             ).addTo(map_7438fba75e70c394cc60efc02b939a3a);
#
#
#             var poly_line_88768584bfbdce3290d135cf2682cbae = L.polyline(
#                 [[60.16960758657717, 24.792630072347652], [60.170948964417576, 24.800208668680035], [60.17536

# %%
m = init_map(zoom=11.5)

visualize_points(df_stations.lat.tolist(), df_stations.lng.tolist(), folium_map=m, color=colors[0], r=1)
visualize_hexagons(df_stations.h3_res7.unique().tolist(), color="black", fill_color=None, w=0.4, folium_map=m)


display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_15e4205bf7be9f73a8b2028d8c42866f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_15e4205bf7be9f73a8b2028d8c42866f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_15e4205bf7be9f73a8b2028d8c42866f = L.map(
#                 &quot;map_15e4205bf7be9f73a8b2028d8c42866f&quot;,
#                 {
#                     center: [60.20085851110746, 24.928136680658007],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3cda4cb7873e450bc4bee7be79a56a06 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3cda4cb7873e450bc4bee7be79a56a06.addTo(map_15e4205bf7be9f73a8b2028d8c42866f);
#
#
#             var circle_marker_681dcdb3f8378801132ef71a6776bdd3 = L.circleMarker(
#                 [60.16582, 24.840319],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8468F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#8468F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_15e4205bf7be9f73a8b2028d8c42866f);
#
#
#             var circle_marker_2b74eb86c1a4285bbf43a829c465ada3 = L.circleMarker(
#                 [60.171524, 24.827467],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8468F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#8468F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_15e4205bf7be9f73a8b2028d8c42866f);
#
#
#             var circle_marker_884c83fb63321fe9c53b0167f445d030 = L.circleMarker(
#                 [60.168266, 24.805758],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8468F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#8468F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_15e4205bf7be9f73a8b2028d8c42866f);
#
#
#             var circle_marker_4c40e381726cdeb7a44c59e8d60053f9 = L.circleMarker(
#                 [60.168143, 24.796136],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8468F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#8468F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_15e4205bf7be9f73a8b2028d8c42866f);
#
#
#             var circle_marker_8f3269e2045c4be572428c70a79ab0ca = L.circleMarker(
#                 [60.171551, 24.802938],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8468F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#8468F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_15e4205bf7be9f73a8b2028d8c42866f);
#
#
#             var circle_marker_91d8b2950d0e2590a036904265c33a52 = L.circleMarker(
#                 [60.173424, 24.810688],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8468F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#8468F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_15e4205bf7be9f73a8b2028d8c42866f);

# %%
# Lat and lng for the return and departure hexagons
selected_hexagon = '861126d17ffffff'
hexa = h3.h3_to_geo(selected_hexagon)

m = init_map(zoom=11.5)

visualize_points(df_stations.lat.tolist(), df_stations.lng.tolist(), folium_map=m, color=colors[0], r=1)
visualize_hexagons(df_stations.h3_res6.unique().tolist(), color="black", fill_color=None, w=0.4, folium_map=m)
#visualize_hexagons([selected_hexagon], color='black', fill_color=colors[0], w=2, folium_map=m, fill_opacity=0.7)
visualize_hexagons([selected_hexagon], color="black", fill_color=None, w=2, folium_map=m)


display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_08d23cf218f5affe821d330bd606e6d8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_08d23cf218f5affe821d330bd606e6d8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_08d23cf218f5affe821d330bd606e6d8 = L.map(
#                 &quot;map_08d23cf218f5affe821d330bd606e6d8&quot;,
#                 {
#                     center: [60.20085851110746, 24.928136680658007],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_24ebeee7e3e186c8e99e7502f802b960 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_24ebeee7e3e186c8e99e7502f802b960.addTo(map_08d23cf218f5affe821d330bd606e6d8);
#
#
#             var circle_marker_9fa951f13b04829f8d6ed82624d3d148 = L.circleMarker(
#                 [60.16582, 24.840319],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8468F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#8468F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_08d23cf218f5affe821d330bd606e6d8);
#
#
#             var circle_marker_be81fafe056d13d7f286fff3144344bf = L.circleMarker(
#                 [60.171524, 24.827467],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8468F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#8468F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_08d23cf218f5affe821d330bd606e6d8);
#
#
#             var circle_marker_95032124eb8137cae08c7c9488c2f3d0 = L.circleMarker(
#                 [60.168266, 24.805758],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8468F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#8468F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_08d23cf218f5affe821d330bd606e6d8);
#
#
#             var circle_marker_cf0c6d3f6cbbdd67d1481cffda69065b = L.circleMarker(
#                 [60.168143, 24.796136],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8468F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#8468F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_08d23cf218f5affe821d330bd606e6d8);
#
#
#             var circle_marker_a70419f2dcf61c268659bc57f6fd3f27 = L.circleMarker(
#                 [60.171551, 24.802938],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8468F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#8468F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_08d23cf218f5affe821d330bd606e6d8);
#
#
#             var circle_marker_5ebc68a3c2bc87328b02cead2618d280 = L.circleMarker(
#                 [60.173424, 24.810688],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8468F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#8468F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_08d23cf218f5affe821d330bd606e6d8);

# %%
col_hexa = 'h3_res8'
col_by = 'ID'

num_stations = df_stations.groupby([col_hexa])[[col_by]].count().reset_index()

choropleth_map(num_stations, hexa_col=col_hexa, column_name = 'ID', min_value=0, color_map_name ='Blues',
               fill_opacity=0.9, color_map_caption = 'Number of stations per hexagon')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0c25de11c1bb51266bc064ce4e90b9e9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0c25de11c1bb51266bc064ce4e90b9e9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0c25de11c1bb51266bc064ce4e90b9e9 = L.map(
#                 &quot;map_0c25de11c1bb51266bc064ce4e90b9e9&quot;,
#                 {
#                     center: [60.20085851110746, 24.928136680658007],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8703a5537d5e8a57cc40ba20997de481 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8703a5537d5e8a57cc40ba20997de481.addTo(map_0c25de11c1bb51266bc064ce4e90b9e9);
#
#
#         function geo_json_fd4bbef9d2bafad4e5aa9f25392df11a_styler(feature) {
#             switch(feature.id) {
#                 case &quot;8808996807fffff&quot;: case &quot;8808996823fffff&quot;: case &quot;8808996825fffff&quot;: case &quot;8808996827fffff&quot;: case &quot;880899682bfffff&quot;: case &quot;8808996833fffff&quot;: case &quot;8808996885fffff&quot;: case &quot;8808996887fffff&quot;: case &quot;88089968a5fffff&quot;: case &quot;88089968b5fffff&quot;: case &quot;88089968b7fffff&quot;: case &quot;88089968b9fffff&quot;: case &quot;880899690bfffff&quot;: case &quot;8808996911fffff&quot;: case &quot;8808996913fffff&quot;: case &quot;8808996917fffff&quot;: case &quot;880899691bfffff&quot;: case &quot;8808996951fffff&quot;: case &quot;8808996985fffff&quot;: case &quot;8808996993fffff&quot;: case &quot;880899699bfffff&quot;: case &quot;88089969a3fffff&quot;: case &quot;88089969b1fffff&quot;: case &quot;88089969b3fffff&quot;: case &quot;88089969b9fffff&quot;: case &quot;88089969d3fffff&quot;: case &quot;88089969ddfffff&quot;: case &quot;88089969ebfffff&quot;: case &quot;8808996d21fffff&quot;: case &quot;8808996d23fffff&quot;: case &quot;8808996d27fffff&quot;: case &quot;8808996d65fffff&quot;: case &quot;8808996d67fffff&quot;: case &quot;881126c209fffff&quot;: case &quot;881126c20dfffff&quot;: case &quot;881126c243fffff&quot;: case &quot;881126c247fffff&quot;: case &quot;881126c249fffff&quot;: case &quot;881126c24bfffff&quot;: case &quot;881126c24dfffff&quot;: case &quot;881126c263fffff&quot;: case &quot;881126c265fffff&quot;: case &quot;881126c267fffff&quot;: case &quot;881126c26bfffff&quot;: case &quot;881126c319fffff&quot;: case &quot;881126c351fffff&quot;: case &quot;881126c359fffff&quot;: case &quot;881126d011fffff&quot;: case &quot;881126d013fffff&quot;: case &quot;881126d019fffff&quot;: case &quot;881126d01dfffff&quot;: case &quot;881126d029fffff&quot;: case &quot;881126d041fffff&quot;: case &quot;881126d043fffff&quot;: case &quot;881126d047fffff&quot;: case &quot;881126d049fffff&quot;: case &quot;881126d051fffff&quot;: case &quot;881126d057fffff&quot;: case &quot;881126d05bfffff&quot;: case &quot;881126d065fffff&quot;: case &quot;881126d085fffff&quot;: case &quot;881126d08dfffff&quot;: case &quot;881126d093fffff&quot;: case &quot;881126d095fffff&quot;: case &quot;881126d097fffff&quot;: case &quot;881126d09bfffff&quot;: case &quot;881126d0a1fffff&quot;: case &quot;881126d0a5fffff&quot;: case &quot;881126d0a9fffff&quot;: case &quot;881126d0abfffff&quot;: case &quot;881126d0b5fffff&quot;: case &quot;881126d0bbfffff&quot;: case &quot;881126d0c1fffff&quot;: case &quot;881126d0c3fffff&quot;: case &quot;881126d0c5fffff&quot;: case &quot;881126d0cdfffff&quot;: case &quot;881126d0d1fffff&quot;: case &quot;881126d0d3fffff&quot;: case &quot;881126d0d7fffff&quot;: case &quot;881126d0d9fffff&quot;: case &quot;881126d0e1fffff&quot;: case &quot;881126d0e9fffff&quot;: case &quot;881126d115fffff&quot;: case &quot;881126d117fffff&quot;: case &quot;881126d149fffff&quot;: case &quot;881126d15bfffff&quot;: case &quot;881126d18bfffff&quot;: case &quot;881126d18dfffff&quot;: case &quot;881126d1c3fffff&quot;: case &quot;881126d1c5fffff&quot;: case &quot;881126d1c7fffff&quot;: case &quot;881126d1cbfffff&quot;: case &quot;881126d1d1fffff&quot;: case &quot;881126d1d3fffff&quot;: case &quot;881126d1d9fffff&quot;: case &quot;881126d1dbfffff&quot;: case &quot;881126d1e5fffff&quot;: case &quot;881126d1e9fffff&quot;: case &quot;881126d1edfffff&quot;: case &quot;881126d203fffff&quot;: case &quot;881126d20bfffff&quot;: case &quot;881126d20dfffff&quot;: case &quot;881126d215fffff&quot;: case &quot;881126d217fffff&quot;: case &quot;881126d21bfffff&quot;: case &quot;881126d223fffff&quot;: case &quot;881126d227fffff&quot;: case &quot;881126d237fffff&quot;: case &quot;881126d239fffff&quot;: case &quot;881126d245fffff&quot;: case &quot;881126d24dfffff&quot;: case &quot;8811

# %%
col_hexa = 'departure_h3_res8'
col_by = "Departure"

num_trips = df_trips.groupby([col_hexa,'departure_date'])[[col_by]].count().reset_index()
num_trips = num_trips.groupby([col_hexa])[[col_by]].mean().reset_index()

choropleth_map(num_trips, hexa_col=col_hexa, column_name = col_by, color_map_name ='coolwarm',
               fill_opacity=0.9, color_map_caption = 'Average number of daily departures per hexagon',
               min_value=0, max_value=roundup(num_trips[col_by].max(),50))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0ed26f38bafb3e7390bedb30d5066579 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0ed26f38bafb3e7390bedb30d5066579&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0ed26f38bafb3e7390bedb30d5066579 = L.map(
#                 &quot;map_0ed26f38bafb3e7390bedb30d5066579&quot;,
#                 {
#                     center: [60.20085851110746, 24.928136680658007],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fb83729f0b33a9f4aa45a9c4f014e8b4 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_fb83729f0b33a9f4aa45a9c4f014e8b4.addTo(map_0ed26f38bafb3e7390bedb30d5066579);
#
#
#         function geo_json_874afd248918e60bb1c6924ff4d70937_styler(feature) {
#             switch(feature.id) {
#                 case &quot;8808996807fffff&quot;: case &quot;8808996823fffff&quot;: case &quot;8808996825fffff&quot;: case &quot;880899682bfffff&quot;: case &quot;8808996833fffff&quot;: case &quot;88089968b7fffff&quot;: case &quot;880899690bfffff&quot;: case &quot;880899691bfffff&quot;: case &quot;88089969d3fffff&quot;: case &quot;88089969ddfffff&quot;: case &quot;88089969ebfffff&quot;: case &quot;8808996d61fffff&quot;: case &quot;8808996d65fffff&quot;: case &quot;881126c22dfffff&quot;: case &quot;881126c263fffff&quot;: case &quot;881126c359fffff&quot;: case &quot;881126d013fffff&quot;: case &quot;881126d019fffff&quot;: case &quot;881126d0a1fffff&quot;: case &quot;881126d0bdfffff&quot;: case &quot;881126d0c5fffff&quot;: case &quot;881126d0cdfffff&quot;: case &quot;881126d0d1fffff&quot;: case &quot;881126d19bfffff&quot;: case &quot;881126d1d3fffff&quot;: case &quot;881126d1dbfffff&quot;: case &quot;881126d1edfffff&quot;: case &quot;881126d217fffff&quot;: case &quot;881126d255fffff&quot;: case &quot;881126d25bfffff&quot;: case &quot;881126d2a9fffff&quot;: case &quot;881126d2c5fffff&quot;: case &quot;881126d2e9fffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#3d50c3&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;8808996821fffff&quot;: case &quot;8808996885fffff&quot;: case &quot;8808996887fffff&quot;: case &quot;88089968b1fffff&quot;: case &quot;88089968b9fffff&quot;: case &quot;8808996911fffff&quot;: case &quot;8808996951fffff&quot;: case &quot;88089969b3fffff&quot;: case &quot;881126c243fffff&quot;: case &quot;881126c267fffff&quot;: case &quot;881126c319fffff&quot;: case &quot;881126d011fffff&quot;: case &quot;881126d049fffff&quot;: case &quot;881126d051fffff&quot;: case &quot;881126d05bfffff&quot;: case &quot;881126d0a5fffff&quot;: case &quot;881126d0d5fffff&quot;: case &quot;881126d0ddfffff&quot;: case &quot;881126d117fffff&quot;: case &quot;881126d18dfffff&quot;: case &quot;881126d1c3fffff&quot;: case &quot;881126d1cbfffff&quot;: case &quot;881126d1d7fffff&quot;: case &quot;881126d1d9fffff&quot;: case &quot;881126d1e9fffff&quot;: case &quot;881126d215fffff&quot;: case &quot;881126d237fffff&quot;: case &quot;881126d2a7fffff&quot;: case &quot;881126d2b7fffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#3e51c5&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;8808996827fffff&quot;: case &quot;8808996989fffff&quot;: case &quot;88089969d5fffff&quot;: case &quot;881126d009fffff&quot;: case &quot;881126d309fffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#516ddb&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;8808996829fffff&quot;: case &quot;88089968a3fffff&quot;: case &quot;880899691dfffff&quot;: case &quot;881126d057fffff&quot;: case &quot;881126d0cbfffff&quot;: case &quot;881126d15bfffff&quot;: case &quot;881126d189fffff&quot;: case &quot;881126d195fffff&quot;: case &quot;881126d1ebfffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#445acc&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;880899682dfffff&quot;: case &quot;88089969b1fffff&quot;: case &quot;88089969b9fffff&quot;: case &quot;881126d053fffff&quot;: case &quot;881126d05dfffff&quot;: case &quot;881126d243fffff&quot;: case &quot;881126d349fffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#465ecf&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;8808996867fffff&quot;: case &quot;881126d1c5fffff&q

# %% [markdown]
# # Own trips
# Selecting trips between two stations (departure from Töölönlahdenkatu and return to Syystie).

# %%
my_trips = df_trips[ (df_trips['Departure station name'] == 'Töölönlahdenkatu') & 
                    (df_trips['Return station name'] == 'Syystie')]

my_trips['Covered distance (km)'] = my_trips['Covered distance (m)']/1000
my_trips['Duration (min.)'] = my_trips['Duration (sec.)']/60
my_trips['Day of the week'] = my_trips['departure_day_name']

my_trips[['Departure', 'Return', 'Departure station name', 'Return station name',
          'Covered distance (km)', 'Duration (min.)', 'Day of the week']]
# Out:
#                    Departure              Return Departure station name  \
# 5575303  2021-08-13 17:22:04 2021-08-13 18:09:32       Töölönlahdenkatu
# 5721690  2021-08-04 16:37:40 2021-08-04 17:25:33       Töölönlahdenkatu
# 11059403 2021-07-10 17:47:51 2021-07-10 18:37:58       Töölönlahdenkatu
#
#          Return station name  Covered distance (km)  Duration (min.)  \
# 5575303              Syystie                 12.489        47.383333
# 5721690              Syystie                 12.078        47.866667
# 11059403             Syystie                 12.078        50.100000
#
#          Day of the week
# 5575303           Friday
# 5721690        Wednesday
# 11059403        Saturday

# %%
# Plot the departure and return locations to the map.
m = visualize_line(my_trips.departure_lat.tolist(), my_trips.departure_lng.tolist(),
               my_trips.return_lat.tolist(), my_trips.return_lng.tolist(), color='black', w=1, folium_map=None)
#visualize_points(df_stations.lat.tolist(), df_stations.lng.tolist(), folium_map=m, color=colors[0], r=1)
visualize_points(my_trips.departure_lat.tolist(), my_trips.departure_lng.tolist(), folium_map=m,
                 color='red', r=4)
visualize_points(my_trips.return_lat.tolist(), my_trips.return_lng.tolist(), folium_map=m,
                 color='blue', r=4)

display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_88c043baee7592ffc0411c8e4a8ecea9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_88c043baee7592ffc0411c8e4a8ecea9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_88c043baee7592ffc0411c8e4a8ecea9 = L.map(
#                 &quot;map_88c043baee7592ffc0411c8e4a8ecea9&quot;,
#                 {
#                     center: [60.20085851110746, 24.928136680658007],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4e7664fa23af4b3048b963c26a667d0f = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_4e7664fa23af4b3048b963c26a667d0f.addTo(map_88c043baee7592ffc0411c8e4a8ecea9);
#
#
#             var poly_line_2eea50651572b67d0e798ae941934808 = L.polyline(
#                 [[60.1721906837527, 24.9393079129956], [60.256671174374, 24.9986055764439]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_88c043baee7592ffc0411c8e4a8ecea9);
#
#
#             var poly_line_f617f604c4a9c2599916bc092203f125 = L.polyline(
#                 [[60.1721906837527, 24.9393079129956], [60.256671174374, 24.9986055764439]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_88c043baee7592ffc0411c8e4a8ecea9);
#
#
#             var poly_line_c98b6c76531715890a5a175ceac9b26d = L.polyline(
#                 [[60.1721906837527, 24.9393079129956], [60.256671174374, 24.9986055764439]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_88c043baee7592ffc0411c8e4a8ecea9);
#
#
#             var circle_marker_3026b1bd59cebdaf570c7fc9353e0a62 = L.circleMarker(
#                 [60.1721906837527, 24.9393079129956],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_88c043baee7592ffc0411c8e4a8ecea9);
#
#
#             var circle_marker_09508dd11ae11b37662c7b520a87f5d4 = L.circleMarker(
#                 [60.1721906837527, 24.9393079129956],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_88c043baee7592ffc0411c8e4a8ecea9);
#
#
#             var circle_marker_c0363ebb29523ebe78d7146f7326ea01 = L.circleMarker(
#                 [60.1721906837527, 24.9393079129956],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCa

# %%
# Visualize the return and departure hexagons
departure_id = my_trips.departure_h3_res7.unique()[0]
return_id = my_trips.return_h3_res7.unique()[0]

ret = h3.h3_to_geo(return_id)
dep = h3.h3_to_geo(departure_id)

m = visualize_line([dep[0]], [dep[1]], [ret[0]], [ret[1]], color='black', w=2, folium_map=None)
#visualize_points(df_stations.lat.tolist(), df_stations.lng.tolist(), folium_map=m, color=colors[0], r=1)
#visualize_points([dep[0]], [dep[1]], folium_map=m, color='red', r=2)
#visualize_points([ret[0]], [ret[1]], folium_map=m, color='red', r=2)
visualize_hexagons([return_id], color="black", fill_color='blue', w=1.5, folium_map=m, fill_opacity=0.5)
visualize_hexagons([departure_id], color="black", fill_color='red', w=1.5, folium_map=m, fill_opacity=0.5)


display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_169b4de3ba2c6addb38b9b7df2426149 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_169b4de3ba2c6addb38b9b7df2426149&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_169b4de3ba2c6addb38b9b7df2426149 = L.map(
#                 &quot;map_169b4de3ba2c6addb38b9b7df2426149&quot;,
#                 {
#                     center: [60.20085851110746, 24.928136680658007],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_832ccef862c981c4d01772cfc5d6efaa = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_832ccef862c981c4d01772cfc5d6efaa.addTo(map_169b4de3ba2c6addb38b9b7df2426149);
#
#
#             var poly_line_9fd199fff405fdee090461a6e67feac4 = L.polyline(
#                 [[60.16813960487212, 24.945598027696235], [60.26084516580375, 24.98778295506447]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_169b4de3ba2c6addb38b9b7df2426149);
#
#
#             var poly_line_f800d83da24c185fc99c825cc9cc7ca1 = L.polyline(
#                 [[60.256018803309864, 25.006615939156987], [60.267929220944474, 25.005044950715057], [60.272754052961965, 24.98620545069655], [60.26566788779166, 24.968948221168734], [60.25375999263491, 24.970531159257433], [60.24893573962262, 24.989359380841318], [60.256018803309864, 25.006615939156987]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1.5}
#             ).addTo(map_169b4de3ba2c6addb38b9b7df2426149);
#
#
#             var poly_line_86eb42f48335be4a15e947e0c025608c = L.polyline(
#                 [[60.17296519641374, 24.92681654054972], [60.16105707716433, 24.928409202475958], [60.15622995599545, 24.947184214851447], [60.1633103831001, 24.964377784162675], [60.175221029708474, 24.962796993345798], [60.18004872239447, 24.944010758516757], [60.17296519641374, 24.92681654054972]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1.5}
#             ).addTo(map_169b4de3ba2c6addb38b9b7df2426149);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Misc

# %%
# Lat and lng for the return and departure hexagons
selected_station = df_stations[df_stations.Name == 'Leppäsuonaukio']
hexa7 = selected_station.h3_res7.values[0]
hexa8= selected_station.h3_res8.values[0]
hexa9= selected_station.h3_res9.values[0]

m = init_map(zoom=11.5)

visualize_hexagons(df_stations.h3_res7.unique().tolist(), color="black", fill_color=None, w=0.1, folium_map=m)
visualize_hexagons(df_stations.h3_res8.unique().tolist(), color="black", fill_color=None, w=0.1, folium_map=m)

visualize_hexagons([hexa7], color='black', fill_color=colors[0], w=1, folium_map=m, fill_opacity=0.3)
visualize_hexagons([hexa8], color='black', fill_color=colors[3], w=1, folium_map=m, fill_opacity=0.3)
#visualize_hexagons([hexa9], color='black', fill_color=colors[2], w=2, folium_map=m, fill_opacity=0.8)
visualize_points([selected_station.lat.values[0]], [selected_station.lng.values[0]], folium_map=m, color='red', r=2)

display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_76c27754142fecf201f81fed1400d30a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_76c27754142fecf201f81fed1400d30a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_76c27754142fecf201f81fed1400d30a = L.map(
#                 &quot;map_76c27754142fecf201f81fed1400d30a&quot;,
#                 {
#                     center: [60.20085851110746, 24.928136680658007],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d69f1120fdad2c3eb6e3516152900c99 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d69f1120fdad2c3eb6e3516152900c99.addTo(map_76c27754142fecf201f81fed1400d30a);
#
#
#             var poly_line_340236f3b8df04c4c1701ce9ae1418ce = L.polyline(
#                 [[60.15424364919416, 24.820610931298923], [60.14943369258939, 24.839376830258075], [60.15652369744344, 24.856525761155346], [60.1684267524381, 24.854909396828152], [60.17323726623457, 24.836132266730562], [60.166144167309504, 24.818982735705195], [60.15424364919416, 24.820610931298923]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 0.1}
#             ).addTo(map_76c27754142fecf201f81fed1400d30a);
#
#
#             var poly_line_6cd466a81165533357602b25f12f4e7b = L.polyline(
#                 [[60.18994360698692, 24.815723014290917], [60.18284741476151, 24.798572891678877], [60.170948964417576, 24.800208668680035], [60.166144167309504, 24.818982735705195], [60.17323726623457, 24.836132266730562], [60.185138255033124, 24.83450832593259], [60.18994360698692, 24.815723014290917]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 0.1}
#             ).addTo(map_76c27754142fecf201f81fed1400d30a);
#
#
#             var poly_line_7f839eeb56dd2584063824ee16767e53 = L.polyline(
#                 [[60.15424364919416, 24.820610931298923], [60.166144167309504, 24.818982735705195], [60.170948964417576, 24.800208668680035], [60.16385269045476, 24.783074034823652], [60.15195471237565, 24.78471404837801], [60.147150467689904, 24.803476881439753], [60.15424364919416, 24.820610931298923]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 0.1}
#             ).addTo(map_76c27754142fecf201f81fed1400d30a);
#
#
#             var poly_line_e0c800b503e251a3ad162f8d20f0dff0 = L.polyline(
#                 [[60.16865177568512, 24.76430304490282], [60.16385269045476, 24.783074034823652], [60.170948964417576, 24.800208668680035], [60.18284741476151, 24.798572891678877], [60.18764705006551, 24.779790654331997], [60.180547684418976, 24.76265544503246], [60.16865177568512, 24.76430304490282]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 0.1}
#             ).addTo(map_76c27754142fecf201f81fed1400d30a);
#
#
#             var poly_line_4d3f29e26ac82302a68d5dd30a9e6ea4 = L.polyline(
#                 [[60.192231265863064, 24.85167336114685], [60.185138255033124, 24.83450832593259], [60.17
