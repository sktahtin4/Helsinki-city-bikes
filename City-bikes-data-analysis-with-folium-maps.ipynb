# %%
import h3
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
import numpy as np
import glob
import os
import datetime

import geopandas as gpd
import shapely
from shapely import wkt
from shapely import Polygon
from shapely.plotting import plot_polygon

from matplotlib.ticker import FuncFormatter


pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 100)

#Set color palette in code
colors = ['#8468F5','#EC74E7','#B2B2B2','#FFCB5C','#46B6E8','#2FD4A1','#333333']
sns.set_palette(sns.color_palette(colors), n_colors = 20)

# %% [markdown]
# # Stations data

# %%
file_path = './bike_data/city-bike-stations-cleaned.csv'
df_stations = pd.read_csv(file_path)

df_stations.head()
# Out:
#     ID            Name            Address   City  Capacity        lng  \
# 0  501       Hanasaari  Hanasaarenranta 1  Espoo        10  24.840319
# 1  503      Keilalahti   Keilalahdentie 2  Espoo        28  24.827467
# 2  505  Westendinasema     Westendintie 1  Espoo        16  24.805758
# 3  507       Golfpolku        Golfpolku 3  Espoo        16  24.796136
# 4  509   Revontulentie   Revontulentie 10  Espoo        30  24.802938
#
#          lat          h3_res6          h3_res7          h3_res8  \
# 0  60.165820  86089969fffffff  87089969affffff  88089969a3fffff
# 1  60.171524  86089969fffffff  870899698ffffff  8808996985fffff
# 2  60.168266  86089969fffffff  87089969effffff  880899698dfffff
# 3  60.168143  86089969fffffff  87089969effffff  88089969ebfffff
# 4  60.171551  86089969fffffff  870899698ffffff  880899698dfffff
#
#            h3_res9  Year  Year_last_used
# 0  89089969a33ffff  2018            2021
# 1  8908996984fffff  2018            2021
# 2  890899698dbffff  2018            2021
# 3  89089969eb7ffff  2018            2021
# 4  890899698d3ffff  2018            2021

# %% [markdown]
# # Data on bike trips

# %%
directory_path = './bike_data/city-bike-trips-cleaned.csv'
df_trips = pd.read_csv(directory_path)

# Change the timestamps into datetime
df_trips['Departure'] = pd.to_datetime(df_trips['Departure'])
df_trips['Return'] = pd.to_datetime(df_trips['Return'])

df_trips['departure_date'] = pd.to_datetime(df_trips['departure_date'])
df_trips['return_date'] = pd.to_datetime(df_trips['return_date'])

df_trips.head()
# Out:
#             Departure              Return  Departure station id  \
# 0 2018-06-30 23:59:56 2018-07-01 00:12:00                    44
# 1 2018-06-30 23:59:33 2018-07-01 00:06:00                    22
# 2 2018-06-30 23:59:27 2018-07-01 00:06:00                    27
# 3 2018-06-30 23:59:23 2018-07-01 00:03:00                   127
# 4 2018-06-30 23:59:23 2018-07-01 00:07:00                    27
#
#   Departure station name  Return station id    Return station name  \
# 0  Sörnäisten metroasema                 70        Sammonpuistikko
# 1  Rautatientori / länsi                 22  Rautatientori / länsi
# 2            Eerikinkatu                 63     Jätkäsaarenlaituri
# 3             Teurastamo                125            Arielinkatu
# 4            Eerikinkatu                 63     Jätkäsaarenlaituri
#
#    Covered distance (m)  Duration (sec.) departure_day_name  \
# 0                3199.0            756.0           Saturday
# 1                 104.0            391.0           Saturday
# 2                1247.0            422.0           Saturday
# 3                 791.0            227.0           Saturday
# 4                1251.0            485.0           Saturday
#
#    departure_weekday  departure_hour  departure_day  departure_month  \
# 0                  5              23             30                6
# 1                  5              23             30                6
# 2                  5              23             30                6
# 3                  5              23             30                6
# 4                  5              23             30                6
#
#   departure_date  departure_year return_day_name  return_weekday  return_hour  \
# 0     2018-06-30            2018          Sunday               6            0
# 1     2018-06-30            2018          Sunday               6            0
# 2     2018-06-30            2018          Sunday               6            0
# 3     2018-06-30            2018          Sunday               6            0
# 4     2018-06-30            2018          Sunday               6            0
#
#    return_day  return_month return_date  return_year  departure_ID  \
# 0           1             7  2018-07-01         2018          44.0
# 1           1             7  2018-07-01         2018          22.0
# 2           1             7  2018-07-01         2018          27.0
# 3           1             7  2018-07-01         2018         127.0
# 4           1             7  2018-07-01         2018          27.0
#
#    departure_lng  departure_lat departure_h3_res6 departure_h3_res7  \
# 0      24.960554      60.187713   861126d07ffffff   871126d06ffffff
# 1      24.939760      60.170606   861126d37ffffff   871126d33ffffff
# 2      24.936642      60.167706   861126d37ffffff   871126d33ffffff
# 3      24.971157      60.189695   861126d07ffffff   871126d06ffffff
# 4      24.936642      60.167706   861126d37ffffff   871126d33ffffff
#
#   departure_h3_res8 departure_h3_res9  return_ID  return_lng  return_lat  \
# 0   881126d061fffff   891126d0603ffff       70.0   24.922411   60.173147
# 1   881126d331fffff   891126d338fffff       22.0   24.939760   60.170606
# 2   881126d339fffff   891126d338bffff       63.0   24.921490   60.161931
# 3   881126d063fffff   891126d063bffff      125.0   24.979739   60.185922
# 4   881126d339fffff   891126d338bffff       63.0   24.921490   60.161931
#
#     return_h3_res6   return_h3_res7   return_h3_res8   return_h3_res9
# 0  861126d37ffffff  871126d30ffffff  881126d303fffff  891126d3027ffff
# 1  861126d37ffffff  871126d33ffffff  881126d331fffff  891126d338fffff
# 2  861126d37ffffff  871126d30ffffff  881126d307fffff  891126d307bffff
# 3  861126d07ffffff  871126d02ffffff  881126d067fffff  891126d066fffff
# 4  861126d37ffffff  871126d30ffffff  881126d307fffff  891126d307bffff

# %% [markdown]
# # Folium visualizations

# %%
from h3 import h3
import folium
import leafmap.foliumap as leafmap

center_lng = df_stations.lng.mean()
center_lat = df_stations.lat.mean()


def init_map(zoom=11):
    return folium.Map(location= [center_lat, center_lng], zoom_start=zoom, tiles="cartodbpositron")

def visualize_hexagons(hexagons, color="black", fill_color="purple", w=2, folium_map=None):
    """
    hexagons is a list of hexcluster. Each hexcluster is a list of hexagons. 
    eg. [[hex1, hex2], [hex3, hex4]]
    """
    polylines = []
    lat = []
    lng = []
    for hex in hexagons:
        polygons = h3.h3_set_to_multi_polygon([hex], geo_json=False)
        # flatten polygons into loops.
        outlines = [loop for polygon in polygons for loop in polygon]
        polyline = [outline + [outline[0]] for outline in outlines][0]
        lat.extend(map(lambda v:v[0],polyline))
        lng.extend(map(lambda v:v[1],polyline))
        polylines.append(polyline)
    
    if folium_map is None:
        m = init_map()
    else:
        m = folium_map
    for polyline in polylines:
        my_PolyLine=folium.PolyLine(locations=polyline, weight=w, color=color, fill_color=fill_color)
        m.add_child(my_PolyLine)
    return m

def visualize_points(lat, lng, color='black', folium_map=None, r=2):
    if folium_map is None:
        m = init_map()
    else:
        m = folium_map
        
    for i in range(0, len(lat)):
        scatter_marker = folium.CircleMarker(location=[lat[i], lng[i]], radius=r, color=color, fill_color=color)
        m.add_child(scatter_marker)
        
    return m
    

def visualize_polygon(polyline, color):
    polyline.append(polyline[0])
    lat = [p[0] for p in polyline]
    lng = [p[1] for p in polyline]
    #m = folium.Map(location=[sum(lat)/len(lat), sum(lng)/len(lng)], zoom_start=13, tiles='cartodbpositron')
    m = folium.Map(location=[center_lat, center_lng], zoom_start=13, tiles='openstreetmap')
    my_PolyLine=folium.PolyLine(locations=polyline,weight=8,color=color)
    m.add_child(my_PolyLine)
    return m

def visualize_line(start_lat, start_lng, end_lat, end_lng, color='red', w=2, folium_map=None):
    if folium_map is None:
        m = init_map()
    else:
        m = folium_map
        
    for i in range(0, len(start_lat)):
        line = folium.PolyLine(locations = [[start_lat[i], start_lng[i]], [end_lat[i], end_lng[i]]],
                               weight=w, color=color)
        m.add_child(line)
    return m

# %%
import folium
from geojson import Feature, Point, FeatureCollection
import json
import matplotlib
import branca
from branca.element import Element

center_lng = df_stations.lng.mean()
center_lat = df_stations.lat.mean()

# Taken from: https://gist.github.com/jens-andersson-2-wcar/7cecb40db1fbc051f2822262be42d11b

def hexagons_dataframe_to_geojson(df, hexa_col, column_name):
    """
    Produce the GeoJSON for a dataframe, constructing the geometry from the "hex_id" column
    and with a property matching the one in column_name
    """    
    list_features = []
    
    for i,row in df.iterrows():
        try:
            geometry_for_row = { "type" : "Polygon",
                                "coordinates": [h3.h3_to_geo_boundary(h=row[hexa_col],geo_json=True)]}
            feature = Feature(geometry = geometry_for_row , id = row[hexa_col],
                              properties = {column_name : row[column_name]})
            list_features.append(feature)
        except:
            print("An exception occurred for hex " + row[hexa_col]) 

    feat_collection = FeatureCollection(list_features)
    geojson_result = json.dumps(feat_collection)
    return geojson_result


def get_color(custom_cm, val, vmin, vmax):
    return matplotlib.colors.to_hex(custom_cm((val-vmin)/(vmax-vmin)))


def choropleth_map(df_aggreg, hexa_col, column_name, border_color = 'black', fill_opacity = 0.7,
                   color_map_name = "Purples", initial_map = None, min_value=None, max_value=None,
                   color_map_caption = None):
    """
    Creates choropleth maps given the aggregated data. initial_map can be an existing map to draw on top of.
    """    
    #colormap
    if min_value==None:
        min_value = df_aggreg[column_name].min()
    if max_value == None:
        max_value = df_aggreg[column_name].max()
        
            
    # the name of the layer just needs to be unique, put something silly there for now:
    name_layer = "Choropleth " + str(df_aggreg)
    
    if initial_map is None:
        initial_map = init_map()

    #create geojson data from dataframe
    geojson_data = hexagons_dataframe_to_geojson(df = df_aggreg, hexa_col=hexa_col, column_name=column_name)

    custom_cm = matplotlib.cm.get_cmap(color_map_name)

    folium.GeoJson(
        geojson_data,
        style_function=lambda feature: {
            'fillColor': get_color(custom_cm, feature['properties'][column_name], vmin=min_value, vmax=max_value),
            'color': border_color,
            'weight': 1,
            'fillOpacity': fill_opacity 
        }, 
        name = name_layer
    ).add_to(initial_map)
    
    # Create a colorbar legend
    color_min = get_color(custom_cm, min_value, vmin=min_value, vmax=max_value)
    color_max = get_color(custom_cm, max_value, vmin=min_value, vmax=max_value)
    color_scale = folium.LinearColormap([color_min, color_max], vmin=min_value, vmax=max_value)
    # Add the colorbar legend to the map
    if color_map_caption == None:
        color_scale.caption = column_name
    else:
        color_scale.caption = color_map_caption
    initial_map.add_child(color_scale)

        

    return initial_map

def add_categorical_legend(m, plot_colors, indexes, text):
    ticks = np.add(indexes, 0.5).tolist()
    colormap = branca.colormap.StepColormap(colors=plot_colors, index=indexes, tick_labels= ticks,
                                            vmin=indexes[0], vmax=indexes[-1]+1)
    colormap.caption = text
    
    m.add_child(colormap)
    e = Element("""
                var ticks = document.querySelectorAll('div.legend g.tick text')
                for(var i = 0; i < ticks.length; i++) {
                    var value = parseFloat(ticks[i].textContent.replace(',', ''))
                    var newvalue = Math.floor(value).toFixed(0).toString()
                    ticks[i].textContent = newvalue
                }
                """)
    html = colormap.get_root()
    html.script.get_root().render()
    html.script.add_child(e)

# %%
m = init_map(zoom=11.5)
use_data = df_stations[df_stations.Year==2016]
visualize_points(use_data.lat.tolist(), use_data.lng.tolist(), folium_map=m, color=colors[0])
use_data = df_stations[df_stations.Year==2017]
visualize_points(use_data.lat.tolist(), use_data.lng.tolist(), folium_map=m, color=colors[1])
use_data = df_stations[df_stations.Year==2018]
visualize_points(use_data.lat.tolist(), use_data.lng.tolist(), folium_map=m, color=colors[2])
use_data = df_stations[df_stations.Year==2019]
visualize_points(use_data.lat.tolist(), use_data.lng.tolist(), folium_map=m, color=colors[3])
use_data = df_stations[df_stations.Year==2020]
visualize_points(use_data.lat.tolist(), use_data.lng.tolist(), folium_map=m, color=colors[4])
use_data = df_stations[df_stations.Year==2021]
visualize_points(use_data.lat.tolist(), use_data.lng.tolist(), folium_map=m, color=colors[5])
add_categorical_legend(m, [colors[0], colors[1], colors[2], colors[3], colors[4], colors[5]], 
                       [2016, 2017, 2018, 2019, 2020, 2021], 'Year station was added')
display(m)

m.save("station_year.html")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1286caecdff2e34cace4d664d582dc5f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1286caecdff2e34cace4d664d582dc5f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1286caecdff2e34cace4d664d582dc5f = L.map(
#                 &quot;map_1286caecdff2e34cace4d664d582dc5f&quot;,
#                 {
#                     center: [60.20085851110744, 24.928136680658042],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fcbf7af4ee8bbefdebe89a954dd5caee = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1286caecdff2e34cace4d664d582dc5f);
#
#
#             var circle_marker_e8fa6a12018f8c1b1233cba7364e2a74 = L.circleMarker(
#                 [60.155369615074, 24.9502114714031],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8468F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#8468F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1286caecdff2e34cace4d664d582dc5f);
#
#
#             var circle_marker_65aee6696a6a282ed35c96d604a28ce3 = L.circleMarker(
#                 [60.1609890692806, 24.9565097715858],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8468F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#8468F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1286caecdff2e34cace4d664d582dc5f);
#
#
#             var circle_marker_626d72a65d253102ff9a4e68b89be22c = L.circleMarker(
#                 [60.1581769029949, 24.9450181631667],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8468F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#8468F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1286caecdff2e34cace4d664d582dc5f);
#
#
#             var circle_marker_835d034ede97f91a2de037841683ffe9 = L.circleMarker(
#                 [60.1609858921764, 24.9417758006418],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8468F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#8468F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1286caecdff2e34cace4d664d582dc5f);
#
#
#             var circle_marker_3442a4b30504bd94310cc83436753d7f = L.circleMarker(
#                 [60.157948291819, 24.9362853002102],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8468F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#8468F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1286caecdff2e34cace4d664d582dc5f);
#
#
#             var circle_marker_eadca0569e452217fa85f6ae614b3b39 = L.circleMarker(
#                 [60.1622283898112, 24.9296476311878],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8468F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#8468F5&quot;, &quot;fillOp

# %%
df_stations.head()
# Out:
#     ID            Name            Address   City  Capacity        lng  \
# 0  501       Hanasaari  Hanasaarenranta 1  Espoo        10  24.840319
# 1  503      Keilalahti   Keilalahdentie 2  Espoo        28  24.827467
# 2  505  Westendinasema     Westendintie 1  Espoo        16  24.805758
# 3  507       Golfpolku        Golfpolku 3  Espoo        16  24.796136
# 4  509   Revontulentie   Revontulentie 10  Espoo        30  24.802938
#
#          lat          h3_res6          h3_res7          h3_res8  \
# 0  60.165820  86089969fffffff  87089969affffff  88089969a3fffff
# 1  60.171524  86089969fffffff  870899698ffffff  8808996985fffff
# 2  60.168266  86089969fffffff  87089969effffff  880899698dfffff
# 3  60.168143  86089969fffffff  87089969effffff  88089969ebfffff
# 4  60.171551  86089969fffffff  870899698ffffff  880899698dfffff
#
#            h3_res9  Year  Year_last_used
# 0  89089969a33ffff  2018            2021
# 1  8908996984fffff  2018            2021
# 2  890899698dbffff  2018            2021
# 3  89089969eb7ffff  2018            2021
# 4  890899698d3ffff  2018            2021

# %%
col_hexa = 'departure_h3_res8'
col_by = "Covered distance (m)"

num_trips = df_trips.groupby([col_hexa,'departure_date'])[[col_by]].mean().reset_index()
num_trips = num_trips.groupby([col_hexa])[[col_by]].mean().reset_index()

choropleth_map(num_trips, hexa_col=col_hexa, column_name = 'Covered distance (m)',
               min_value=1200, max_value=4200, fill_opacity=0.9)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_38e4c3befe1fee110193e6deac707ade {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_38e4c3befe1fee110193e6deac707ade&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_38e4c3befe1fee110193e6deac707ade = L.map(
#                 &quot;map_38e4c3befe1fee110193e6deac707ade&quot;,
#                 {
#                     center: [60.20085851110744, 24.928136680658042],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_61aa59aad8fb078034a9f837ec7b320e = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_38e4c3befe1fee110193e6deac707ade);
#
#
#         function geo_json_4231fc3584a63e9500657b843f75793c_styler(feature) {
#             switch(feature.id) {
#                 case &quot;8808996807fffff&quot;: case &quot;88089969b1fffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#786db2&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;8808996821fffff&quot;: case &quot;88089969c7fffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#e3e2ef&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;8808996823fffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c2c3df&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;8808996825fffff&quot;: case &quot;8808996989fffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#dbdbec&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;8808996827fffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ddddec&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;8808996829fffff&quot;: case &quot;881126c269fffff&quot;: case &quot;881126d1b3fffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d9d9ea&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;880899682bfffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#8582bc&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;880899682dfffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#e8e7f2&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;8808996833fffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#6a51a3&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;8808996867fffff&quot;: case &quot;881126c229fffff&quot;: case &quot;881126d339fffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#cecee5&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;8808996885fffff&quot;: case &quot;8808996981fffff&quot;: case &quot;88089969cdfffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#e1e0ee&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;8808996887fffff&quot;: case &quot;8808996995fffff&quot;: case &quot;88089969c1fffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#e9e8f2&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;88089968a1fffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#dcdcec&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;88089968a3fffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f1f0f6&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;88089968a5fffff&quot;: case &quot;88089969ddfffff&quot;: case &quot;881126d0cdfffff&quot;: case &quot;881126d223fffff&quot;: case &quot;881126d2a5fffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#8986be&q

# %%
m = init_map(zoom=11.5)
visualize_hexagons(df_stations.h3_res8.unique().tolist(), color="black", fill_color=None, w=0.6, folium_map=m)
visualize_hexagons(df_stations.h3_res7.unique().tolist(), color="gray", fill_color=None, w=3, folium_map=m)
visualize_hexagons(df_stations.h3_res6.unique().tolist(), color="dimgray", fill_color=None, w=4, folium_map=m)



visualize_points(df_stations.lat.tolist(), df_stations.lng.tolist(), folium_map=m, color=colors[0], r=2)
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_009fda930981a861c8c360e0d369d01b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_009fda930981a861c8c360e0d369d01b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_009fda930981a861c8c360e0d369d01b = L.map(
#                 &quot;map_009fda930981a861c8c360e0d369d01b&quot;,
#                 {
#                     center: [60.20085851110744, 24.928136680658042],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c55a64fa1213bee1d7a4dbe7f4480044 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_009fda930981a861c8c360e0d369d01b);
#
#
#             var poly_line_241d7205b5e6b9121f39a21b186a9eca = L.polyline(
#                 [[60.17150188544707, 24.849313413544458], [60.17016295641157, 24.841728972338363], [60.16574934264519, 24.839741759510503], [60.16267455960363, 24.845337116707608], [60.16401304040454, 24.852920312898643], [60.1684267524381, 24.854909396828152], [60.17150188544707, 24.849313413544458]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 0.6}
#             ).addTo(map_009fda930981a861c8c360e0d369d01b);
#
#
#             var poly_line_c15b9a7555a20878579b231fdbc60d19 = L.polyline(
#                 [[60.166144167309504, 24.818982735705195], [60.1674840971856, 24.826563633429117], [60.17189761244241, 24.82854897506533], [60.17497109911463, 24.822951547775556], [60.17363072084349, 24.81536940638303], [60.16921730433863, 24.813385936027945], [60.166144167309504, 24.818982735705195]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 0.6}
#             ).addTo(map_009fda930981a861c8c360e0d369d01b);
#
#
#             var poly_line_d228f4a790f0013f82030b3ee59277ac = L.polyline(
#                 [[60.167876650341505, 24.805806188634453], [60.16921730433863, 24.813385936027945], [60.17363072084349, 24.81536940638303], [60.17670338440036, 24.809771258053612], [60.17536228192808, 24.80219026766528], [60.170948964417576, 24.800208668680035], [60.167876650341505, 24.805806188634453]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 0.6}
#             ).addTo(map_009fda930981a861c8c360e0d369d01b);
#
#
#             var poly_line_6374895ba6bc30217935755822db1f6d = L.polyline(
#                 [[60.16346330781702, 24.80382448366571], [60.167876650341505, 24.805806188634453], [60.170948964417576, 24.800208668680035], [60.16960758657717, 24.792630072347652], [60.16519434324245, 24.79065023804344], [60.16212237851493, 24.796247129328403], [60.16346330781702, 24.80382448366571]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 0.6}
#             ).addTo(map_009fda930981a861c8c360e0d369d01b);
#
#
#             var poly_line_e952274cccca89296c4fc370285

# %%
col_hexa = 'h3_res8'
col_by = 'ID'

num_stations = df_stations.groupby([col_hexa])[[col_by]].count().reset_index()

choropleth_map(num_stations, hexa_col=col_hexa, column_name = 'ID', min_value=0, color_map_name ='coolwarm',
               fill_opacity=0.9, color_map_caption = 'Number of stations per hexagon')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_874face1e98b8e3c296005b6db077de8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_874face1e98b8e3c296005b6db077de8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_874face1e98b8e3c296005b6db077de8 = L.map(
#                 &quot;map_874face1e98b8e3c296005b6db077de8&quot;,
#                 {
#                     center: [60.20085851110744, 24.928136680658042],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3c036174cdab68e8629f751e0de4bf95 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_874face1e98b8e3c296005b6db077de8);
#
#
#         function geo_json_78cc7e78c843c436a76536f8f4e1fbae_styler(feature) {
#             switch(feature.id) {
#                 case &quot;8808996821fffff&quot;: case &quot;880899682dfffff&quot;: case &quot;8808996867fffff&quot;: case &quot;88089968a1fffff&quot;: case &quot;88089968a9fffff&quot;: case &quot;88089968b1fffff&quot;: case &quot;8808996919fffff&quot;: case &quot;880899691dfffff&quot;: case &quot;8808996957fffff&quot;: case &quot;880899695bfffff&quot;: case &quot;8808996981fffff&quot;: case &quot;8808996983fffff&quot;: case &quot;8808996995fffff&quot;: case &quot;88089969c1fffff&quot;: case &quot;88089969c3fffff&quot;: case &quot;88089969c9fffff&quot;: case &quot;88089969cdfffff&quot;: case &quot;8808996d25fffff&quot;: case &quot;8808996d2dfffff&quot;: case &quot;8808996d61fffff&quot;: case &quot;881126c229fffff&quot;: case &quot;881126c22dfffff&quot;: case &quot;881126c269fffff&quot;: case &quot;881126d001fffff&quot;: case &quot;881126d009fffff&quot;: case &quot;881126d00bfffff&quot;: case &quot;881126d00dfffff&quot;: case &quot;881126d02dfffff&quot;: case &quot;881126d053fffff&quot;: case &quot;881126d055fffff&quot;: case &quot;881126d05dfffff&quot;: case &quot;881126d063fffff&quot;: case &quot;881126d0a7fffff&quot;: case &quot;881126d0bdfffff&quot;: case &quot;881126d0c9fffff&quot;: case &quot;881126d0d5fffff&quot;: case &quot;881126d0ddfffff&quot;: case &quot;881126d0e3fffff&quot;: case &quot;881126d14bfffff&quot;: case &quot;881126d15dfffff&quot;: case &quot;881126d189fffff&quot;: case &quot;881126d191fffff&quot;: case &quot;881126d195fffff&quot;: case &quot;881126d197fffff&quot;: case &quot;881126d19bfffff&quot;: case &quot;881126d19dfffff&quot;: case &quot;881126d1b3fffff&quot;: case &quot;881126d1d7fffff&quot;: case &quot;881126d1ddfffff&quot;: case &quot;881126d1ebfffff&quot;: case &quot;881126d205fffff&quot;: case &quot;881126d207fffff&quot;: case &quot;881126d209fffff&quot;: case &quot;881126d219fffff&quot;: case &quot;881126d21dfffff&quot;: case &quot;881126d229fffff&quot;: case &quot;881126d22bfffff&quot;: case &quot;881126d233fffff&quot;: case &quot;881126d243fffff&quot;: case &quot;881126d249fffff&quot;: case &quot;881126d253fffff&quot;: case &quot;881126d265fffff&quot;: case &quot;881126d26bfffff&quot;: case &quot;881126d2a5fffff&quot;: case &quot;881126d2adfffff&quot;: case &quot;881126d2b7fffff&quot;: case &quot;881126d313fffff&quot;: case &quot;881126d31dfffff&quot;: case &quot;881126d32bfffff&quot;: case &quot;881126d335fffff&quot;: case &quot;881126d337fffff&quot;: case &quot;881126d345fffff&quot;: case &quot;881126d347fffff&quot;: case &quot;881126d349fffff&quot;: case &quot;881126d34dfffff&quot;: case &quot;881126d369fffff&quot;: case &quot;881126d72dfffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#82a6fb&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;8808996829fffff&quot;: case &quot;88089968a3fffff&quot;: case &quot;88089968a7fffff&quot;: case &quot;88089968bdfffff&quot;: case &quot;8808996987fffff&quot;: case &quot;8808996989fffff&quot;: case &quot;88089969c7fffff&quot;: case &quot;881126d027fffff&quot;: case &quot;881126d045fffff&quot;: case &quot;881126d067fffff&quot;: case &quot;881126d0cbfffff&quot;: case &quot;881126d221fffff&quot;: case &quot;881126d225fffff&quot;: case &quot;881126d22dfffff&quot;: case &quot;881126d267fffff&quot;: case &quot;881126d303fffff&quot;: case &quot;881126d307fffff&quot;: case &quot;881126d311fffff&quot;: case &quot;881126d333fffff&quot;: case &quot;881126d33bfffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#aac7fd&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 1};

# %%
col_hexa = 'departure_h3_res8'
col_by = "Departure"

num_trips = df_trips.groupby([col_hexa,'departure_date'])[[col_by]].count().reset_index()
num_trips = num_trips.groupby([col_hexa])[[col_by]].mean().reset_index()

choropleth_map(num_trips, hexa_col=col_hexa, column_name = col_by, color_map_name ='coolwarm',
               fill_opacity=0.9, color_map_caption = 'Number of departure per hexagon',
               min_value=0, max_value=950)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dc64aa908e2788aaa03e4d4da2c1ee9d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dc64aa908e2788aaa03e4d4da2c1ee9d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dc64aa908e2788aaa03e4d4da2c1ee9d = L.map(
#                 &quot;map_dc64aa908e2788aaa03e4d4da2c1ee9d&quot;,
#                 {
#                     center: [60.20085851110744, 24.928136680658042],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0df4e0d80046e990dc19bdb87640c5ee = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_dc64aa908e2788aaa03e4d4da2c1ee9d);
#
#
#         function geo_json_f6e703c3ae35545b6faccc637c7a0ed0_styler(feature) {
#             switch(feature.id) {
#                 case &quot;8808996821fffff&quot;: case &quot;8808996885fffff&quot;: case &quot;8808996887fffff&quot;: case &quot;88089968b1fffff&quot;: case &quot;88089968b9fffff&quot;: case &quot;8808996911fffff&quot;: case &quot;8808996951fffff&quot;: case &quot;88089969b3fffff&quot;: case &quot;881126c243fffff&quot;: case &quot;881126c267fffff&quot;: case &quot;881126c319fffff&quot;: case &quot;881126d011fffff&quot;: case &quot;881126d049fffff&quot;: case &quot;881126d051fffff&quot;: case &quot;881126d05bfffff&quot;: case &quot;881126d0a5fffff&quot;: case &quot;881126d0d5fffff&quot;: case &quot;881126d0ddfffff&quot;: case &quot;881126d117fffff&quot;: case &quot;881126d18dfffff&quot;: case &quot;881126d1c3fffff&quot;: case &quot;881126d1cbfffff&quot;: case &quot;881126d1d7fffff&quot;: case &quot;881126d1d9fffff&quot;: case &quot;881126d1e9fffff&quot;: case &quot;881126d215fffff&quot;: case &quot;881126d237fffff&quot;: case &quot;881126d2a7fffff&quot;: case &quot;881126d2b7fffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#3e51c5&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;8808996827fffff&quot;: case &quot;8808996989fffff&quot;: case &quot;88089969d5fffff&quot;: case &quot;881126d009fffff&quot;: case &quot;881126d309fffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#516ddb&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;8808996829fffff&quot;: case &quot;88089968a3fffff&quot;: case &quot;880899691dfffff&quot;: case &quot;881126d057fffff&quot;: case &quot;881126d0cbfffff&quot;: case &quot;881126d15bfffff&quot;: case &quot;881126d189fffff&quot;: case &quot;881126d195fffff&quot;: case &quot;881126d1ebfffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#445acc&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;880899682dfffff&quot;: case &quot;88089969b1fffff&quot;: case &quot;88089969b9fffff&quot;: case &quot;881126d053fffff&quot;: case &quot;881126d05dfffff&quot;: case &quot;881126d243fffff&quot;: case &quot;881126d349fffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#465ecf&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;8808996867fffff&quot;: case &quot;881126d1c5fffff&quot;: case &quot;881126d21dfffff&quot;: case &quot;881126d233fffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#4358cb&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;88089968a1fffff&quot;: case &quot;881126d055fffff&quot;: case &quot;881126d1ddfffff&quot;: case &quot;881126d36bfffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#4b64d5&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;88089968a5fffff&quot;: case &quot;88089968b5fffff&quot;: case &quot;880899699bfffff&quot;: case &quot;8808996d23fffff&quot;: case &quot;8808996d27fffff&quot;: case &quot;881126c20dfffff&quot;: case &quot;881126c247fffff&quot;: case &quot;881126c24bfffff&quot;: case &quot;881126c24dfffff&quot;: case &quot;881126c26bfffff&quot;: case &quot;881126d085fffff&quot;: case &quot;881126d08dfffff&quot;: case &quot;881126d0a9fffff&quot;: case &quot;881126d0abfffff&quot;: case &quot;881126d0bbfffff&quot;: case &quot;881126d0c1fffff&quot;: case &quot;881126d0d7fffff&quot;: case &quot;881126d0d9ff

# %%
m = init_map(zoom=11.5)
visualize_hexagons(df_stations.h3_res6.unique().tolist(), color="black", fill_color=None, w=1.5, folium_map=m)
visualize_points(df_stations.lat.tolist(), df_stations.lng.tolist(), folium_map=m, color=colors[0], r=1)
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b8081f227374c75fbcc8df6e44488830 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b8081f227374c75fbcc8df6e44488830&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b8081f227374c75fbcc8df6e44488830 = L.map(
#                 &quot;map_b8081f227374c75fbcc8df6e44488830&quot;,
#                 {
#                     center: [60.20085851110744, 24.928136680658042],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8094a331c74234cbacd5f396dc5d072d = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b8081f227374c75fbcc8df6e44488830);
#
#
#             var poly_line_307d4ed5399260f50031c69ebfe1134f = L.polyline(
#                 [[60.147150467689904, 24.803476881439753], [60.15652369744344, 24.856525761155346], [60.187420192445906, 24.870461733016352], [60.2089386314828, 24.831257120622112], [60.19954342955819, 24.778147285113814], [60.16865177568512, 24.76430304490282], [60.147150467689904, 24.803476881439753]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1.5}
#             ).addTo(map_b8081f227374c75fbcc8df6e44488830);
#
#
#             var poly_line_36da460461be19a3e91ef93ab4e04965 = L.polyline(
#                 [[60.221021511098954, 24.738907318216466], [60.211590848594156, 24.68585412172275], [60.18070411894643, 24.672101642957504], [60.15924311266795, 24.71131057260581], [60.16865177568512, 24.76430304490282], [60.19954342955819, 24.778147285113814], [60.221021511098954, 24.738907318216466]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1.5}
#             ).addTo(map_b8081f227374c75fbcc8df6e44488830);
#
#
#             var poly_line_8ebda5b334b2e626d70283ebbec212d6 = L.polyline(
#                 [[60.147150467689904, 24.803476881439753], [60.16865177568512, 24.76430304490282], [60.15924311266795, 24.71131057260581], [60.128355150294944, 24.697552576856012], [60.1068709280325, 24.73669553699206], [60.1162575972822, 24.78962739592896], [60.147150467689904, 24.803476881439753]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1.5}
#             ).addTo(map_b8081f227374c75fbcc8df6e44488830);
#
#
#             var poly_line_efca14c7a5a73f5055629b95ccf2c698 = L.polyline(
#                 [[60.2089386314828, 24.831257120622112], [60.187420192445906, 24.870461733016352], [60.19677983831024, 24.92362795620145], [60.227679858526784, 24.937650839431566], [60.249215474043446, 24.898415553329844], [60.23983387790115, 24.845188030130462], [60.2089386314828, 24.831257120622112]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1.5}
#             ).addTo(map_b8081f227374c75fbcc8df6e44488830);
#
#
#             var poly_line_6f03185e00ffed7f06a09b62a51

# %%
df_stations.Year.value_counts()
# Out:
# 2018    117
# 2021    106
# 2017     97
# 2019     94
# 2016     41
# 2020      2
# Name: Year, dtype: int64

# %% [markdown]
# # Own trips

# %%
my_trips = df_trips[ (df_trips['Departure station name'] == 'Töölönlahdenkatu') & 
                    (df_trips['Return station name'] == 'Syystie')]

my_trips['Covered distance (km)'] = my_trips['Covered distance (m)']/1000
my_trips['Duration (min.)'] = my_trips['Duration (sec.)']/60
my_trips['Day of the week'] = my_trips['departure_day_name']

my_trips[['Departure', 'Return', 'Departure station name', 'Return station name',
          'Covered distance (km)', 'Duration (min.)', 'Day of the week']]
# Out:
#                    Departure              Return Departure station name  \
# 5575303  2021-08-13 17:22:04 2021-08-13 18:09:32       Töölönlahdenkatu
# 5721690  2021-08-04 16:37:40 2021-08-04 17:25:33       Töölönlahdenkatu
# 11059403 2021-07-10 17:47:51 2021-07-10 18:37:58       Töölönlahdenkatu
#
#          Return station name  Covered distance (km)  Duration (min.)  \
# 5575303              Syystie                 12.489        47.383333
# 5721690              Syystie                 12.078        47.866667
# 11059403             Syystie                 12.078        50.100000
#
#          Day of the week
# 5575303           Friday
# 5721690        Wednesday
# 11059403        Saturday

# %%
m = visualize_line(my_trips.departure_lat.tolist(), my_trips.departure_lng.tolist(),
               my_trips.return_lat.tolist(), my_trips.return_lng.tolist(), color='black', w=1, folium_map=None)
visualize_points(df_stations.lat.tolist(), df_stations.lng.tolist(), folium_map=m, color=colors[0], r=1)
visualize_points(my_trips.departure_lat.tolist(), my_trips.departure_lng.tolist(), folium_map=m,
                 color='red', r=4)
visualize_points(my_trips.return_lat.tolist(), my_trips.return_lng.tolist(), folium_map=m,
                 color='red', r=4)

display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ff1d38097c308b7fa3cab03276403d2a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ff1d38097c308b7fa3cab03276403d2a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ff1d38097c308b7fa3cab03276403d2a = L.map(
#                 &quot;map_ff1d38097c308b7fa3cab03276403d2a&quot;,
#                 {
#                     center: [60.20085851110744, 24.928136680658042],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8464aef2bf9bb4615ecb7b10009e7767 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ff1d38097c308b7fa3cab03276403d2a);
#
#
#             var poly_line_a8f207cf51ffc5034388d6aa33850278 = L.polyline(
#                 [[60.1721906837527, 24.9393079129956], [60.256671174374, 24.9986055764439]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_ff1d38097c308b7fa3cab03276403d2a);
#
#
#             var poly_line_a7392c57e170abf023b59c286fa1675d = L.polyline(
#                 [[60.1721906837527, 24.9393079129956], [60.256671174374, 24.9986055764439]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_ff1d38097c308b7fa3cab03276403d2a);
#
#
#             var poly_line_978b64b58fd56310d7c4ad798b3c3d1a = L.polyline(
#                 [[60.1721906837527, 24.9393079129956], [60.256671174374, 24.9986055764439]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_ff1d38097c308b7fa3cab03276403d2a);
#
#
#             var circle_marker_14783521e69f2707adacd483aa8931d9 = L.circleMarker(
#                 [60.16582, 24.840319],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8468F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#8468F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ff1d38097c308b7fa3cab03276403d2a);
#
#
#             var circle_marker_26ca0544bbb3b8577b428cf45a565e7c = L.circleMarker(
#                 [60.171524, 24.827467],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8468F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#8468F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ff1d38097c308b7fa3cab03276403d2a);
#
#
#             var circle_marker_481044de649cf18cba31f642d178afac = L.circleMarker(
#                 [60.168266, 24.805758],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8468F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&qu

# %%
departure_id = my_trips.departure_h3_res7.unique()[0]
return_id = my_trips.return_h3_res7.unique()[0]

similar_trips = df_trips[ (df_trips.departure_h3_res7 == departure_id) & (df_trips.return_h3_res7 == return_id)]
similar_trips['Covered distance (km)'] = similar_trips['Covered distance (m)']/1000
similar_trips['Duration (min.)'] = similar_trips['Duration (sec.)']/60
similar_trips['Day of the week'] = similar_trips['departure_day_name']

similar_trips[['Departure', 'Return', 'Covered distance (km)', 'Duration (min.)', 'Day of the week']]
# Out:
#                    Departure              Return  Covered distance (km)  \
# 4732832  2021-09-04 22:24:12 2021-09-04 23:28:53                 12.141
# 5575303  2021-08-13 17:22:04 2021-08-13 18:09:32                 12.489
# 5675659  2021-08-06 23:35:58 2021-08-08 12:10:09                  4.128
# 5721690  2021-08-04 16:37:40 2021-08-04 17:25:33                 12.078
# 9518793  2021-06-28 10:17:37 2021-06-28 10:27:35                  3.394
# 9826518  2021-06-12 00:37:40 2021-06-12 01:27:09                 12.055
# 11059403 2021-07-10 17:47:51 2021-07-10 18:37:58                 12.078
# 11111635 2021-07-07 22:33:09 2021-07-07 23:17:39                 11.286
# 11133208 2021-07-06 23:23:34 2021-07-07 00:24:30                 11.177
# 11133211 2021-07-06 23:22:21 2021-07-07 00:20:33                 11.284
#
#           Duration (min.) Day of the week
# 4732832         64.600000        Saturday
# 5575303         47.383333          Friday
# 5675659       2194.116667          Friday
# 5721690         47.866667       Wednesday
# 9518793          9.950000          Monday
# 9826518         49.416667        Saturday
# 11059403        50.100000        Saturday
# 11111635        44.400000       Wednesday
# 11133208        60.850000         Tuesday
# 11133211        58.116667         Tuesday

# %%
# Lat and lng for the return and departure hexagons
ret = h3.h3_to_geo(return_id)
dep = h3.h3_to_geo(departure_id)

m = visualize_line([dep[0]], [dep[1]], [ret[0]], [ret[1]], color='black', w=2, folium_map=None)
visualize_points(df_stations.lat.tolist(), df_stations.lng.tolist(), folium_map=m, color=colors[0], r=1)
visualize_points([dep[0]], [dep[1]], folium_map=m, color='red', r=2)
visualize_points([ret[0]], [ret[1]], folium_map=m, color='red', r=2)
visualize_hexagons([return_id], color="black", fill_color=colors[3], w=1.5, folium_map=m)
visualize_hexagons([departure_id], color="black", fill_color=colors[4], w=1.5, folium_map=m)




display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_20bf5d729259b070b4b45e7fbc9775eb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_20bf5d729259b070b4b45e7fbc9775eb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_20bf5d729259b070b4b45e7fbc9775eb = L.map(
#                 &quot;map_20bf5d729259b070b4b45e7fbc9775eb&quot;,
#                 {
#                     center: [60.20085851110744, 24.928136680658042],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_50987fcd326ce924705c6d7959dd6ed8 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_20bf5d729259b070b4b45e7fbc9775eb);
#
#
#             var poly_line_3914a01bd2da4bf176238c3acd19612a = L.polyline(
#                 [[60.16813960487212, 24.94559802769623], [60.26084516580374, 24.98778295506447]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_20bf5d729259b070b4b45e7fbc9775eb);
#
#
#             var circle_marker_73895cc22f67233fdaab69d30c4bf9d0 = L.circleMarker(
#                 [60.16582, 24.840319],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8468F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#8468F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_20bf5d729259b070b4b45e7fbc9775eb);
#
#
#             var circle_marker_bc5e80fc87193a4c8947237b03c4d278 = L.circleMarker(
#                 [60.171524, 24.827467],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8468F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#8468F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_20bf5d729259b070b4b45e7fbc9775eb);
#
#
#             var circle_marker_fcabdfde570aee1589f6445b77322c97 = L.circleMarker(
#                 [60.168266, 24.805758],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8468F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#8468F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_20bf5d729259b070b4b45e7fbc9775eb);
#
#
#             var circle_marker_578b8246f5822afde6861f9ec1f0ff30 = L.circleMarker(
#                 [60.168143, 24.796136],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8468F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#8468F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_20bf5d729259b070b4b45e7fbc9775eb);
#
#
#             var circle_marker_604893b7e38bd65df8760ee08c68b8fb = L.circleMarker(
#                 [60.171551, 24.802938],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8468F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#8468F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;line
